# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Generate some data:

# %%
from sgdglm.api.models.nb_glm import Simulator

sim = Simulator(num_observations=2000, num_features=100)
sim.generate_sample_description(num_batches=0)
sim.generate()

# %% [markdown]
# Run differential expression test:

# %%
# %%capture
import diffxpy as de

test = de.test(sim.input_data, full_formula="~ 1 + condition", reduced_formula="~ 1")
# Out:
# Estimating reduced model...
# Graph was finalized.
# Running local_init_op.
# Done running local_init_op.
# Step: 1	loss: 11.194789
# Step: 2	loss: 11.053830
# Step: 3	loss: 10.943685
# Step: 4	loss: 10.909215
# Step: 5	loss: 10.881078
# Step: 6	loss: 10.838408
# Step: 7	loss: 10.812055
# Step: 8	loss: 10.784152
# Step: 9	loss: 10.771590
# Step: 10	loss: 10.760477
# Step: 11	loss: 10.748507
# Step: 12	loss: 10.730677
# Step: 13	loss: 10.730536
# Step: 14	loss: 10.728131
# Step: 15	loss: 10.704255
# Step: 16	loss: 10.703126
# Step: 17	loss: 10.702482
# Step: 18	loss: 10.695520
# Step: 19	loss: 10.702497
# Step: 20	loss: 10.697556
# Step: 21	loss: 10.690488
# Step: 22	loss: 10.683449
# Step: 23	loss: 10.682461
# Step: 24	loss: 10.681785
# Step: 25	loss: 10.683600
# Step: 26	loss: 10.682918
# Step: 27	loss: 10.678368
# Step: 28	loss: 10.678770
# Step: 29	loss: 10.676191
# Step: 30	loss: 10.677426
# Step: 31	loss: 10.678070
# Step: 32	loss: 10.670468
# Step: 33	loss: 10.675025
# ...

# %%
pval = test.likelihood_ratio_test()
pval
# Out:
# array([2.17557094e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.79070758e-10,
#        0.00000000e+00, 5.53945871e-04, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 2.49125132e-08, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
# ...
